# %%
pub_f96d17636afd4b7688d0e007847ad734

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

API_KEY = "pub_f96d17636afd4b7688d0e007847ad734"

url = f"https://newsdata.io/api/1/latest?apikey={API_KEY}&country=in&q=social"

# %%
response = requests.get(url)

# %%
data = response.json()

# %%
data
# Out:
# {'status': 'success',
#  'totalResults': 4785,
#  'results': [{'article_id': '6b481296ed5e2ef0bea6e1d6614c165f',
#    'link': 'https://indianexpress.com/article/world/us-iran-switzerland-talks-qatar-pakistan-statement-lucerne-10751074/',
#    'title': 'Sanctions, oversight, and Lebanon: Takeaways from US-Iran talks in Switzerland',
#    'description': 'The US and Iran have agreed to establish a High Level Committee to provide “political oversight on the mediation,” the statement said.',
#    'content': 'ONLY AVAILABLE IN PAID PLANS',
#    'keywords': ['us iran 60 day roadmap',
#     'iran frozen assets qatar',
#     'lebanon deconfliction cell',
#     'pakistan qatar mediation middle east',
#     'trump iran truth social threats',
#     'strait of hormuz commercial shipping',
#     'bürgenstock negotiations outcomes',
#     'us iran talks switzerland',
#     'iran oil sanctions waivers',
#     'west asia ceasefire framework 2026',
#     'jd vance mohammad bagher ghalibaf',
# ...
