# %%
age = int(input("Enter the age: "))
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# ## Control Statements
#
# 1. Conditional Statements
# 2. Iterative statements

# %% [markdown]
# ### Conditional Statements

# %%
#Conditional statements
age = 19
if age>=18:
    print("Yes, you are allowed")
# Out:
# Yes, you are allowed

# %%
age >=18
# Out:
# True

# %%
username = input("Enter username: ")

if username =="dhruvverma":
    print("Correct user name")
    
    password = input("Enter the password: ")
    
    if password == "dhruv123":
        print("Password is corret")
    else:
        print("password is incorrect")
else:
    print("incorrect username")
# Out:
# incorrect username

# %%
age = 17

# %%
if age >=18:
    print("you are allowed")
else:
    print("you are not allowed")
# Out:
# you are not allowed

# %%
marks = int(input("Enter the marks: "))

if marks > 90:
    print("Grade A")
elif marks>80:
    print("Grade B")
elif marks >70:
    print("Grade C")
elif marks > 60:
    print("Grade D")
else:
    print("Fail")

# %%
age = 12

# %% [markdown]
# Inline if statement

# %%
"valid" if age >=18 else "Invalid"
# Out:
# 'Invalid'

# %%
age = int(input("Enter the age: "))
salary = int(input("Enter the salary: "))

if age > 20 and salary > 40000:
    print("valid")
else:
    print("Invalid")
# Out:
# Invalid

# %%
age = int(input("Enter the age: "))
salary = int(input("Enter the salary: "))
if age > 20 or salary > 40000:
    print("valid")
else:
    print("Invalid")
# Out:
# Invalid

# %% [markdown]
# ### Iterative Statements

# %% [markdown]
# for,
# while

# %%
numbers = [2,3,4,5,6,7,2,3,4]

print(type(numbers))
# Out:
# <class 'list'>

# %%
for num in numbers:
    print(num)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 2
# 3
# 4

# %%
for ch in "Dhruv":
    print(ch)
# Out:
# D
# h
# r
# u
# v

# %% [markdown]
# range(stop)<br>
# range(start,stop)<br>
# range(start,stop,step)

# %%
for i in range(20):
    print(i)

# %%
for i in range(5,20):
    print(i)

# %%
for i in range(2,22,2):
    print(i)

# %%
num = 1
while num<=20:
    print("Hello")
    num = num + 1
