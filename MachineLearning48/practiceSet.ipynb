# %%
data = {
    "age": [
        22, 25, None, 28, 35,
        40, None, 30, 27, 45,
        50, None, 33, 29, 41,
        38, None, 26, 34, 48
    ],
    
    "salary": [
        25000, 30000, 28000, None, 45000,
        50000, 52000, None, 32000, 60000,
        None, 70000, 48000, 35000, None,
        55000, 58000, None, 42000, 65000
    ],
    
    "department": [
        "HR", "IT", "IT", None, "Finance",
        "HR", None, "Marketing", "IT", "Finance",
        "HR", None, "Marketing", "IT", "Finance",
        None, "HR", "Marketing", None, "IT"
    ],
    
    "experience_years": [
        1, 3, 2, None, 10,
        15, None, 5, 4, 20,
        None, 25, 8, 6, None,
        12, 14, None, 9, 18
    ],
    
    "education": [
        "Bachelors", "Masters", None, "Bachelors", "PhD",
        "Masters", "Bachelors", None, "Masters", "PhD",
        None, "PhD", "Masters", None, "Bachelors",
        "Masters", None, "Bachelors", "Masters", None
    ]
}
