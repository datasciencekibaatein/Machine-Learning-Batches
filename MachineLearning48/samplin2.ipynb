# %%
from sklearn.datasets import load_iris

# %%
import pandas as pd

# %%
rawData = load_iris()

X = rawData.data
y = rawData.target

# %%
X = pd.DataFrame(rawData.data, columns=rawData.feature_names)

# %%
y = pd.Series(rawData.target,name="target")

# %%
df = pd.concat([df,sr],axis=1)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df['target'].value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
#Random Sampling

sample_random = df.sample(n=30,random_state=42)

# %%
sample_random
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 73                 6.1               2.8                4.7               1.2
# 18                 5.7               3.8                1.7               0.3
# 118                7.7               2.6                6.9               2.3
# 78                 6.0               2.9                4.5               1.5
# 76                 6.8               2.8                4.8               1.4
# 31                 5.4               3.4                1.5               0.4
# 64                 5.6               2.9                3.6               1.3
# 141                6.9               3.1                5.1               2.3
# 68                 6.2               2.2                4.5               1.5
# 82                 5.8               2.7                3.9               1.2
# 110                6.5               3.2                5.1               2.0
# ...

# %%
sample_random['target'].value_counts()
# Out:
# target
# 2    11
# 0    10
# 1     9
# Name: count, dtype: int64

# %% [markdown]
# To preserve the class ratio we will use stratify sampling

# %%
from sklearn.model_selection import train_test_split

X_sample,_,y_sample,_ = train_test_split(X,y,train_size=15,stratify=y,random_state=42)

# %%
y_sample.value_counts()
# Out:
# target
# 1    5
# 0    5
# 2    5
# Name: count, dtype: int64
