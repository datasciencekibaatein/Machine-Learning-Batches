# %%
import pandas as pd

df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 0     1152  2024-07-27   2024-08-04  Customer_327  Electronics   West
# 1      500  2024-02-23   2024-03-04  Customer_426  Electronics  North
# 2     1337  2022-04-27   2022-05-06  Customer_379  Electronics   East
# 3     1033  2022-02-24   2022-03-02  Customer_381         Food   West
# 4      281  2023-11-16   2023-11-19  Customer_208    Furniture  South
#
#      Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount
# 0  Wholesale        15     271.72             True     3668.220
# 1     Online        17     433.52            False     7369.840
# 2     Retail         6     434.97            False     2609.820
# 3  Wholesale        12     283.51             True     3061.908
# 4     Retail        15      49.16             True      663.660

# %%
df.groupby('Category')['SalesAmount'].sum()
# Out:
# Category
# Clothing       1284500.648
# Electronics    1317491.969
# Food           1120211.564
# Furniture      1195676.483
# Name: SalesAmount, dtype: float64

# %%
df.groupby(['Category','Channel'])['SalesAmount'].sum()
# Out:
# Category     Channel
# Clothing     Online       488179.532
#              Retail       410826.261
#              Wholesale    385494.855
# Electronics  Online       522072.729
#              Retail       382439.822
#              Wholesale    412979.418
# Food         Online       417919.216
#              Retail       319909.354
#              Wholesale    382382.994
# Furniture    Online       407141.930
#              Retail       396308.063
#              Wholesale    392226.490
# Name: SalesAmount, dtype: float64

# %%
df.groupby(['Category','Channel'])[['SalesAmount','Quantity']].sum()
# Out:
#                        SalesAmount  Quantity
# Category    Channel
# Clothing    Online      488179.532      1988
#             Retail      410826.261      1831
#             Wholesale   385494.855      1570
# Electronics Online      522072.729      1996
#             Retail      382439.822      1636
#             Wholesale   412979.418      1667
# Food        Online      417919.216      1903
#             Retail      319909.354      1453
#             Wholesale   382382.994      1463
# Furniture   Online      407141.930      1770
#             Retail      396308.063      1606
#             Wholesale   392226.490      1508

# %%
df.groupby(['Category','Channel'])[['SalesAmount','Quantity']].agg(['sum','mean','min','max'])
# Out:
#                       SalesAmount                                Quantity  \
#                               sum         mean     min       max      sum
# Category    Channel
# Clothing    Online     488179.532  2638.808281   6.550  8244.180     1988
#             Retail     410826.261  2321.052322  51.084  9059.010     1831
#             Wholesale  385494.855  2379.597870  11.169  8082.540     1570
# Electronics Online     522072.729  2932.992860  49.710  8586.860     1996
#             Retail     382439.822  2390.248887  14.980  8457.480     1636
#             Wholesale  412979.418  2415.084316  45.030  7627.932     1667
# Food        Online     417919.216  2211.212783  36.729  8015.530     1903
#             Retail     319909.354  2118.604993  20.870  8246.880     1453
#             Wholesale  382382.994  2583.668878   7.830  7333.578     1463
# Furniture   Online     407141.930  2326.525314  25.600  8029.134     1770
# ...

# %%
df.pivot_table(values='SalesAmount',index='Category',columns=['Region','Channel'],aggfunc=["max",'min'])
# Out:
#                   max                                                   \
# Region           East                         North
# Channel        Online    Retail Wholesale    Online   Retail Wholesale
# Category
# Clothing     7489.458  6956.880   6524.01  8081.080  6316.05  8082.540
# Electronics  7938.010  7528.110   5583.63  7723.188  6767.84  7627.932
# Food         7137.900  7911.790   7174.72  7612.160  6654.15  7333.578
# Furniture    7112.817  8265.627   8957.74  6816.609  6993.76  8320.176
#
#                                                     ...       min          \
# Region          South                         West  ...      East   North
# Channel        Online    Retail Wholesale   Online  ... Wholesale  Online
# Category                                            ...
# Clothing     8244.180  6733.584  6391.170  7745.44  ...    17.690  48.820
# Electronics  8200.020  6585.630  6480.927  8586.86  ...    63.927  95.589
# ...

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate'])

# %%
df.dtypes
# Out:
# OrderID                     int64
# OrderDate          datetime64[us]
# ShipmentDate                  str
# CustomerName                  str
# Category                      str
# Region                        str
# Channel                       str
# Quantity                    int64
# UnitPrice                 float64
# DiscountApplied              bool
# SalesAmount               float64
# dtype: object

# %%
df['Month'] = df['OrderDate'].dt.month

# %%
df['Year'] = df['OrderDate'].dt.year

# %%
df
# Out:
#       OrderID  OrderDate ShipmentDate  CustomerName     Category Region  \
# 0        1152 2024-07-27   2024-08-04  Customer_327  Electronics   West
# 1         500 2024-02-23   2024-03-04  Customer_426  Electronics  North
# 2        1337 2022-04-27   2022-05-06  Customer_379  Electronics   East
# 3        1033 2022-02-24   2022-03-02  Customer_381         Food   West
# 4         281 2023-11-16   2023-11-19  Customer_208    Furniture  South
# ...       ...        ...          ...           ...          ...    ...
# 1995      894 2022-06-05   2022-06-08  Customer_247    Furniture  South
# 1996     1837 2024-03-30   2024-04-08  Customer_427         Food  North
# 1997     1702 2023-06-01   2023-06-07  Customer_135    Furniture   East
# 1998      957 2024-02-14   2024-02-19   Customer_64    Furniture   West
# 1999      939 2024-12-13   2024-12-22   Customer_25  Electronics  North
#
#         Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount  Month  \
# ...

# %%
df.groupby('Month')['SalesAmount'].sum()
# Out:
# Month
# 1     453905.519
# 2     396955.530
# 3     400772.983
# 4     432722.772
# 5     446728.349
# 6     331446.459
# 7     381639.783
# 8     374819.086
# 9     342857.713
# 10    442697.002
# 11    399410.655
# 12    513924.813
# Name: SalesAmount, dtype: float64

# %%
df.pivot_table(index=['Year','Month'],values='SalesAmount',columns='Region',aggfunc='sum')
# Out:
# Region           East      North      South       West
# Year Month
# 2022 1      23971.670  74492.099  31183.699  60846.832
#      2      22518.739  33436.634  29033.585  37365.439
#      3      18148.220  25002.176  24567.725  35406.386
#      4      40838.120  29917.332  37754.291  17934.764
#      5      56189.285  26106.711  44094.854  46502.429
#      6      12066.908  20127.901  26760.244  46997.179
#      7      42322.381  20759.910  14859.805  50324.614
#      8      16543.371  23490.295  20450.466  48726.520
#      9      14514.010  51458.714  14859.576  22010.206
#      10     14240.701  15942.316  40793.206  32422.320
#      11     46324.604  37321.927  21970.922  26198.008
#      12     55602.623  29421.291  68126.695  48783.820
# 2023 1      44474.198  27912.553  35740.669  40484.586
#      2      16436.853  47289.814  34778.069  34618.988
#      3      37543.606  46437.207  40279.570  18688.144
#      4      23715.577  39764.915  60218.994  17970.403
# ...

# %%
print(df['SalesAmount'].sum())
# Out:
# 4917880.664

# %%
len(df[df['DiscountApplied']==True])
# Out:
# 1009

# %%
len(df[df['DiscountApplied']==False])
# Out:
# 991

# %%
len(df[df['DiscountApplied']==True])/len(df) * 100
# Out:
# 50.449999999999996

# %%
print(df[df['Channel']=='Online']['SalesAmount'].sum()/df['SalesAmount'].sum()*100)
# Out:
# 37.319193620026404
