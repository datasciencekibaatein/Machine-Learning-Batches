# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = {
    'Name':['A','B','C'],
    'Age':[23,25,22]
}

# %%
df = pd.DataFrame(data)

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df1 = pd.DataFrame([[1,2],[3,4]],columns=['A','B'])
df1
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head(10)
# Out:
#    OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 0     1152  2024-07-27   2024-08-04  Customer_327  Electronics   West
# 1      500  2024-02-23   2024-03-04  Customer_426  Electronics  North
# 2     1337  2022-04-27   2022-05-06  Customer_379  Electronics   East
# 3     1033  2022-02-24   2022-03-02  Customer_381         Food   West
# 4      281  2023-11-16   2023-11-19  Customer_208    Furniture  South
# 5     1659  2022-05-26   2022-06-01  Customer_237     Clothing  South
# 6     1329  2022-07-25   2022-07-28   Customer_98         Food   West
# 7      211  2024-04-01   2024-04-02  Customer_271     Clothing  South
# 8     1261  2022-07-11   2022-07-14  Customer_359  Electronics   East
# 9     1910  2024-07-28   2024-08-03  Customer_233  Electronics  North
#
#      Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount
# 0  Wholesale        15     271.72             True     3668.220
# 1     Online        17     433.52            False     7369.840
# ...

# %%
df.tail(10)
# Out:
#       OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 1990     1694  2023-10-10   2023-10-11  Customer_258  Electronics  North
# 1991      371  2024-06-14   2024-06-17  Customer_269     Clothing   West
# 1992     1304  2024-05-18   2024-05-23  Customer_149    Furniture  South
# 1993     1450  2024-06-29   2024-07-07  Customer_137  Electronics  North
# 1994      435  2024-06-09   2024-06-16  Customer_407    Furniture  North
# 1995      894  2022-06-05   2022-06-08  Customer_247    Furniture  South
# 1996     1837  2024-03-30   2024-04-08  Customer_427         Food  North
# 1997     1702  2023-06-01   2023-06-07  Customer_135    Furniture   East
# 1998      957  2024-02-14   2024-02-19   Customer_64    Furniture   West
# 1999      939  2024-12-13   2024-12-22   Customer_25  Electronics  North
#
#         Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount
# 1990  Wholesale        18     470.86             True     7627.932
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          2000 non-null   int64
#  1   OrderDate        2000 non-null   str
#  2   ShipmentDate     2000 non-null   str
#  3   CustomerName     2000 non-null   str
#  4   Category         2000 non-null   str
#  5   Region           2000 non-null   str
#  6   Channel          2000 non-null   str
#  7   Quantity         2000 non-null   int64
#  8   UnitPrice        2000 non-null   float64
#  9   DiscountApplied  2000 non-null   bool
#  10  SalesAmount      2000 non-null   float64
# dtypes: bool(1), float64(2), int64(2), str(6)
# memory usage: 158.3 KB

# %%
df.describe()
# Out:
#            OrderID     Quantity    UnitPrice  SalesAmount
# count  2000.000000  2000.000000  2000.000000  2000.000000
# mean   1000.500000    10.195500   253.750990  2458.940332
# std     577.494589     5.419868   141.864924  2024.978250
# min       1.000000     1.000000     5.120000     6.550000
# 25%     500.750000     5.750000   130.815000   812.524500
# 50%    1000.500000    10.000000   253.375000  1901.762500
# 75%    1500.250000    15.000000   376.955000  3679.098000
# max    2000.000000    19.000000   499.840000  9059.010000

# %%
df.shape
# Out:
# (2000, 11)

# %%
sr = pd.Series([23,123,34,3,54])

# %%
sr
# Out:
# 0     23
# 1    123
# 2     34
# 3      3
# 4     54
# dtype: int64

# %%
df[['CustomerName','SalesAmount']].head()
# Out:
#    CustomerName  SalesAmount
# 0  Customer_327     3668.220
# 1  Customer_426     7369.840
# 2  Customer_379     2609.820
# 3  Customer_381     3061.908
# 4  Customer_208      663.660

# %%
df.loc[0:10,'CustomerName']
# Out:
# 0     Customer_327
# 1     Customer_426
# 2     Customer_379
# 3     Customer_381
# 4     Customer_208
# 5     Customer_237
# 6      Customer_98
# 7     Customer_271
# 8     Customer_359
# 9     Customer_233
# 10    Customer_247
# Name: CustomerName, dtype: str

# %%
df.iloc[0:10,0:5]
# Out:
#    OrderID   OrderDate ShipmentDate  CustomerName     Category
# 0     1152  2024-07-27   2024-08-04  Customer_327  Electronics
# 1      500  2024-02-23   2024-03-04  Customer_426  Electronics
# 2     1337  2022-04-27   2022-05-06  Customer_379  Electronics
# 3     1033  2022-02-24   2022-03-02  Customer_381         Food
# 4      281  2023-11-16   2023-11-19  Customer_208    Furniture
# 5     1659  2022-05-26   2022-06-01  Customer_237     Clothing
# 6     1329  2022-07-25   2022-07-28   Customer_98         Food
# 7      211  2024-04-01   2024-04-02  Customer_271     Clothing
# 8     1261  2022-07-11   2022-07-14  Customer_359  Electronics
# 9     1910  2024-07-28   2024-08-03  Customer_233  Electronics

# %%
df[df['Quantity']>15]
# Out:
#       OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 1         500  2024-02-23   2024-03-04  Customer_426  Electronics  North
# 7         211  2024-04-01   2024-04-02  Customer_271     Clothing  South
# 9        1910  2024-07-28   2024-08-03  Customer_233  Electronics  North
# 10        189  2022-01-02   2022-01-09  Customer_247  Electronics   West
# 15        241  2024-12-08   2024-12-09  Customer_295    Furniture  North
# ...       ...         ...          ...           ...          ...    ...
# 1979      336  2023-12-05   2023-12-09   Customer_58  Electronics   East
# 1982       78  2023-10-10   2023-10-17  Customer_212     Clothing   East
# 1986      181  2023-04-18   2023-04-22  Customer_355    Furniture   East
# 1990     1694  2023-10-10   2023-10-11  Customer_258  Electronics  North
# 1996     1837  2024-03-30   2024-04-08  Customer_427         Food  North
#
#         Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount
# ...

# %%
temp = df[(df['Region']=="North")&(df['DiscountApplied']==True)][['OrderID','OrderDate','Category','Channel','Quantity','SalesAmount']]

# %%
temp.to_csv("SpecificRecords.csv")

# %%
pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
temp.to_excel("SpecificRecords.xlsx")
